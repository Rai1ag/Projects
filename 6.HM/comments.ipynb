# %% [markdown]
# Вы отлично справились с заданием.
# Все правильно сделали. Конечно, данные немного корявые.
# Если посмотреть на них внимательнее, то увидите аномальные значения и в весе и росте и давление верхнее ниже давления нижнего.
# Можно было еще посмотреть на сами цифры. И удалить эти аномалии.
# Результат 0,74 - это стандартный по данным из задачи.
# Вы молодец!
