# %% [markdown]
# - Подробный анализ данных, но обратите внимание, что не всегда мультиколлинеарность плохо влияет на модель, например, для Случайного леса не сильно страдает от мультиколлинеарности, потому что они разделяет пространство признаков и не полагается на линейные комбинации признаков.
#
# - Отличные визуализации, хорошо было бы интерпретировать то, что получили на графиках.
#
# - Отлично справились с обучением моделей, но обратите внимание, что для логистической регрессии хорошо было бы стандартизировать данные, для линейных моделей это важно. Также при подборе гиперпараметров, чтобы избежать предупреждений старайтесь ставить гиперпараметры, которые могут работать вместе.
#
# - Хорошо было бы попробовать собрать свой многослойный персептрон для проверки работы НС, но MLPClassifier тоже подойдет.
#
# - К сожалению, нет инференса.
